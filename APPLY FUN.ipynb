# %%
import pandas as pd
import numpy as np
from IPython.display import display

students = pd.Series(data=[180, 175, 168, 190],
                     index=['Vik', 'Mehdi', 'Bella', 'Chriss'])
display(students)
print(type(students))
# Out:
# Vik       180
# Mehdi     175
# Bella     168
# Chriss    190
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
def cm_to_feet(h):
    return np.round(h/30.48, 2)

print(students.apply(cm_to_feet))
# Out:
# Vik       5.91
# Mehdi     5.74
# Bella     5.51
# Chriss    6.23
# dtype: float64

# %%
data = pd.DataFrame({'EmployeeName': ['Callen Dunkley', 'Sarah Rayner', 'Jeanette Sloan', 'Kaycee Acosta', 'Henri Conroy', 'Emma Peralta', 'Martin Butt', 'Alex Jensen', 'Kim Howarth', 'Jane Burnett'],
                    'Department': ['Accounting', 'Engineering', 'Engineering', 'HR', 'HR', 'HR', 'Data Science', 'Data Science', 'Accounting', 'Data Science'],
                    'HireDate': [2010, 2018, 2012, 2014, 2014, 2018, 2020, 2018, 2020, 2012],
                    'Sex': ['M', 'F', 'F', 'F', 'M', 'F', 'M', 'M', 'M', 'F'],
                    'Birthdate': ['04/09/1982', '14/04/1981', '06/05/1997', '08/01/1986', '10/10/1988', '12/11/1992', '10/04/1991', '16/07/1995', '08/10/1992', '11/10/1979'],
                    'Weight': [78, 80, 66, 67, 90, 57, 115, 87, 95, 57],
                    'Height': [176, 160, 169, 157, 185, 164, 195, 180, 174, 165],
                    'Kids': [2, 1, 0, 1, 1, 0, 2, 0, 3, 1]
                    })
display(data)
# Out:
#      EmployeeName    Department  HireDate Sex   Birthdate  Weight  Height  \
# 0  Callen Dunkley    Accounting      2010   M  04/09/1982      78     176
# 1    Sarah Rayner   Engineering      2018   F  14/04/1981      80     160
# 2  Jeanette Sloan   Engineering      2012   F  06/05/1997      66     169
# 3   Kaycee Acosta            HR      2014   F  08/01/1986      67     157
# 4    Henri Conroy            HR      2014   M  10/10/1988      90     185
# 5    Emma Peralta            HR      2018   F  12/11/1992      57     164
# 6     Martin Butt  Data Science      2020   M  10/04/1991     115     195
# 7     Alex Jensen  Data Science      2018   M  16/07/1995      87     180
# 8     Kim Howarth    Accounting      2020   M  08/10/1992      95     174
# 9    Jane Burnett  Data Science      2012   F  11/10/1979      57     165
#
#    Kids
# 0     2
# 1     1
# 2     0
# 3     1
# 4     1
# 5     0
# 6     2
# 7     0
# 8     3
# 9     1

# %%
data
# Out:
#      EmployeeName    Department  HireDate Sex   Birthdate  Weight  Height  \
# 0  Callen Dunkley    Accounting      2010   M  04/09/1982      78     176
# 1    Sarah Rayner   Engineering      2018   F  14/04/1981      80     160
# 2  Jeanette Sloan   Engineering      2012   F  06/05/1997      66     169
# 3   Kaycee Acosta            HR      2014   F  08/01/1986      67     157
# 4    Henri Conroy            HR      2014   M  10/10/1988      90     185
# 5    Emma Peralta            HR      2018   F  12/11/1992      57     164
# 6     Martin Butt  Data Science      2020   M  10/04/1991     115     195
# 7     Alex Jensen  Data Science      2018   M  16/07/1995      87     180
# 8     Kim Howarth    Accounting      2020   M  08/10/1992      95     174
# 9    Jane Burnett  Data Science      2012   F  11/10/1979      57     165
#
#    Kids
# 0     2
# 1     1
# 2     0
# 3     1
# 4     1
# 5     0
# 6     2
# 7     0
# 8     3
# 9     1

# %%
df = data.copy()

# %%
data['FirstName'] = data['EmployeeName'].apply(lambda x : x.split()[0])
data['LastName'] = data['EmployeeName'].apply(lambda x : x.split()[1])
display(data)

# %%
def test(x):
    x = x.split()[0]
    return x

# %%
df['firstname2'] = df['EmployeeName'].apply(test)

# %%
df.head(4)
# Out:
#      EmployeeName   Department  HireDate Sex   Birthdate  Weight  Height  \
# 0  Callen Dunkley   Accounting      2010   M  04/09/1982      78     176
# 1    Sarah Rayner  Engineering      2018   F  14/04/1981      80     160
# 2  Jeanette Sloan  Engineering      2012   F  06/05/1997      66     169
# 3   Kaycee Acosta           HR      2014   F  08/01/1986      67     157
#
#    Kids          firstname firstname2
# 0     2  [Callen, Dunkley]     Callen
# 1     1    [Sarah, Rayner]      Sarah
# 2     0  [Jeanette, Sloan]   Jeanette
# 3     1   [Kaycee, Acosta]     Kaycee

# %%
def test2(X):
    X = X*10
    return X

# %%
df['ggg'] = df['HireDate'].apply(test2)

# %%
df.head(1)
# Out:
#      EmployeeName  Department  HireDate Sex   Birthdate  Weight  Height  Kids  \
# 0  Callen Dunkley  Accounting      2010   M  04/09/1982      78     176     2
#
#            firstname firstname2    ggg
# 0  [Callen, Dunkley]     Callen  20100

# %%
def test4(x):
    if x == 'M':
        x = 100
    return x

# %%
df['asa'] = df['Sex'].apply(test4)

# %%
df
# Out:
#      EmployeeName    Department  HireDate Sex   Birthdate  Weight  Height  \
# 0  Callen Dunkley    Accounting      2010   M  04/09/1982      78     176
# 1    Sarah Rayner   Engineering      2018   F  14/04/1981      80     160
# 2  Jeanette Sloan   Engineering      2012   F  06/05/1997      66     169
# 3   Kaycee Acosta            HR      2014   F  08/01/1986      67     157
# 4    Henri Conroy            HR      2014   M  10/10/1988      90     185
# 5    Emma Peralta            HR      2018   F  12/11/1992      57     164
# 6     Martin Butt  Data Science      2020   M  10/04/1991     115     195
# 7     Alex Jensen  Data Science      2018   M  16/07/1995      87     180
# 8     Kim Howarth    Accounting      2020   M  08/10/1992      95     174
# 9    Jane Burnett  Data Science      2012   F  11/10/1979      57     165
#
#    Kids          firstname firstname2    ggg  asa
# 0     2  [Callen, Dunkley]     Callen  20100  100
# 1     1    [Sarah, Rayner]      Sarah  20180    F
# 2     0  [Jeanette, Sloan]   Jeanette  20120    F
# 3     1   [Kaycee, Acosta]     Kaycee  20140    F
# 4     1    [Henri, Conroy]      Henri  20140  100
# 5     0    [Emma, Peralta]       Emma  20180    F
# 6     2     [Martin, Butt]     Martin  20200  100
# 7     0     [Alex, Jensen]       Alex  20180  100
# 8     3     [Kim, Howarth]        Kim  20200  100
# 9     1    [Jane, Burnett]       Jane  20120    F

# %%
#map functiom

# %%
import pandas as pd
import numpy as np
technologies= {
    'Fee' :[22000,25000,23000,np.NaN,26000],
    'Duration':['30days','50days','30days','35days','40days']
          }
df = pd.DataFrame(technologies)
print(df)
# Out:
#        Fee Duration
# 0  22000.0   30days
# 1  25000.0   50days
# 2  23000.0   30days
# 3      NaN   35days
# 4  26000.0   40days

# %%
df
# Out:
#        Fee Duration
# 0  22000.0   30days
# 1  25000.0   50days
# 2  23000.0   30days
# 3      NaN   35days
# 4  26000.0   40days

# %%
df['Fee1'] = df['Fee'].map(lambda x: x - (x*10/100))
print(df)
# Out:
#        Fee Duration     Fee1
# 0  22000.0   30days  19800.0
# 1  25000.0   50days  22500.0
# 2  23000.0   30days  20700.0
# 3      NaN   35days      NaN
# 4  26000.0   40days  23400.0

# %%
df['Fee11'] = df['Fee'].apply(lambda x: x - (x*10/100))

# %%
df
# Out:
#        Fee Duration     Fee1    Fee11
# 0  22000.0   30days  19800.0  19800.0
# 1  25000.0   50days  22500.0  22500.0
# 2  23000.0   30days  20700.0  20700.0
# 3      NaN   35days      NaN      NaN
# 4  26000.0   40days  23400.0  23400.0

# %%
def fun1(x):
    return x/100
df['Fee22'] = df['Fee'].map(lambda x:fun1(x))

# %%
df
# Out:
#        Fee Duration     Fee1    Fee11  Fee22
# 0  22000.0   30days  19800.0  19800.0  220.0
# 1  25000.0   50days  22500.0  22500.0  250.0
# 2  23000.0   30days  20700.0  20700.0  230.0
# 3      NaN   35days      NaN      NaN    NaN
# 4  26000.0   40days  23400.0  23400.0  260.0

# %%
dict_map = {'30days':'35 Days','50days':'55 Days',
            '40days':'45 Days'}
updateSer = df['Duration'].map(dict_map)
df['Duration22'] = updateSer
df
# Out:
#        Fee Duration     Fee1    Fee11  Fee22 Duration22
# 0  22000.0   30days  19800.0  19800.0  220.0    35 Days
# 1  25000.0   50days  22500.0  22500.0  250.0    55 Days
# 2  23000.0   30days  20700.0  20700.0  230.0    35 Days
# 3      NaN   35days      NaN      NaN    NaN        NaN
# 4  26000.0   40days  23400.0  23400.0  260.0    45 Days

# %%
def add_3(x):
    return x+3
df2 = df[].apply(add_3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5392/836143514.py in <module>
#       1 def add_3(x):
#       2        return x+3
# ----> 3 df2 = df.apply(add_3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp/ipykernel_5392/836143514.py in add_3(x)
#       1 def add_3(x):
# ----> 2        return x+3
#       3 df2 = df.apply(add_3)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#      90     @unpack_zerodim_and_defer("__add__")
#      91     def __add__(self, other):
# ---> 92         return self._arith_method(other, operator.add)
#      93
#      94     @unpack_zerodim_and_defer("__radd__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    5524
#    5525         with np.errstate(all="ignore"):
# -> 5526             result = ops.arithmetic_op(lvalues, rvalues, op)
#    5527
#    5528         return self._construct_result(result, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#     129
#     130         if mask.any():
# --> 131             result[mask] = op(xrav[mask], y)
#     132
#     133     np.putmask(result, ~mask, np.nan)
#
# TypeError: can only concatenate str (not "int") to str

# %%
import pandas as pd
import numpy as np
data = [(3,5,7), (2,4,6),(5,8,9)]
df = pd.DataFrame(data, columns = ['A','B','C'])
print(df)
# Out:
#    A  B  C
# 0  3  5  7
# 1  2  4  6
# 2  5  8  9

# %%
df
# Out:
#    A  B  C
# 0  3  5  7
# 1  2  4  6
# 2  5  8  9

# %%
def add_4(x):
    return x+4

# %%
df["B1"] = df["B"].apply(add_4)
df
# Out:
#    A  B  C  B1
# 0  3  5  7   9
# 1  2  4  6   8
# 2  5  8  9  12

# %%
#apply fun for all columns
df = df.apply(add_4)

# %%
df
# Out:
#    A   B   C  B1
# 0  7   9  11  13
# 1  6   8  10  12
# 2  9  12  13  16

# %%
#df = pd.DataFrame(data, columns = ['A','B','C'])
df[['A','B']] = df[['A','B']].apply(add_3)

# %%
df
# Out:
#     A   B   C  B1
# 0  10  12  11  13
# 1   9  11  10  12
# 2  12  15  13  16

# %%
df = pd.DataFrame(data, columns = ['A','B','C'])
df[['A','B']] = df[['A','B']].apply(add_3)

# %%
df
# Out:
#    A   B  C
# 0  6   8  7
# 1  5   7  6
# 2  8  11  9

# %%
def add_2(x):
    return x+2
df = df.transform(add_2)
print(df)
# Out:
#     A   B   C
# 0   8  10   9
# 1   7   9   8
# 2  10  13  11

# %%
df
# Out:
#     A   B   C
# 0   8  10   9
# 1   7   9   8
# 2  10  13  11

# %%
df
# Out:
#        Fee Duration
# 0  22000.0   30days
# 1  25000.0   50days
# 2  23000.0   30days
# 3      NaN   35days
# 4  26000.0   40days

# %%
df['aaa']= [12,23,45,np.nan,33].

# %%
df
# Out:
#        Fee Duration   aaa
# 0  22000.0   30days  12.0
# 1  25000.0   50days  23.0
# 2  23000.0   30days  45.0
# 3      NaN   35days   NaN
# 4  26000.0   40days  33.0

# %%
def test(x):
    if pd.isnull(x['Fee']):
        if x['Duration'] == '35days':
            return 40000
    else:
        return x[0]

# %%
df['ppp112'] = df.apply(test, axis = 1)

# %%
df
# Out:
#        Fee Duration  aaa aaa22   aaa221    aaa16   aaa164  aaa1644  aaa16443  \
# 0  22000.0   30days  NaN   NaN      NaN      NaN  22000.0  22000.0   22000.0
# 1  25000.0   50days  NaN   NaN      NaN      NaN  25000.0  25000.0   25000.0
# 2  23000.0   30days  NaN   NaN      NaN      NaN  23000.0  23000.0   23000.0
# 3      NaN   35days  NaN   NaN  40000.0  40000.0  40000.0  40000.0   40000.0
# 4  26000.0   40days  NaN   NaN      NaN      NaN  26000.0  26000.0   26000.0
#
#    aaa164435555      ppp     ppp1    ppp11   ppp112
# 0       22000.0  22000.0  22000.0  22000.0  22000.0
# 1       25000.0  25000.0  25000.0  25000.0  25000.0
# 2       23000.0  23000.0  23000.0  23000.0  23000.0
# 3       40000.0  40000.0      NaN      NaN  40000.0
# 4       26000.0  26000.0  26000.0  26000.0  26000.0

# %%
df['aaa221'].isnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: aaa221, dtype: bool

# %%
def test1(x):
    if pd.isnull(x['Fee']):
        if x['Duration'] == '35days':
            return 40000
    else:
        return x[0]
